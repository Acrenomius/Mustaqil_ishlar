# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X = np.linspace(-10, 10, 100).reshape(-1, 1)

# %%
np.random.seed(42)

# %%
y = 2 * X**2 + 3 * X + 1 + np.random.normal(0, 10, size=X.shape)

# %%
y_reshaped = np.hstack([y, y, y])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_reshaped, test_size=0.2, random_state=42)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_poly)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R^2 Score:", r2)
# Out:
# Mean Absolute Error (MAE): 6.006414772521421
# Mean Squared Error (MSE): 61.963304503949814
# Root Mean Squared Error (RMSE): 7.871677362795671
# R^2 Score: 0.9787067070796317

# %%
plt.scatter(X_test, y_test[:, 0], label='Haqiqiy (1-ustun)', color='blue')
plt.scatter(X_test, y_test[:, 1], label='Haqiqiy (2-ustun)', color='green')
plt.scatter(X_test, y_test[:, 2], label='Haqiqiy (3-ustun)', color='orange')

plt.plot(X_test, y_pred[:, 0], color='red', label='Bashorat (1-ustun)')
plt.plot(X_test, y_pred[:, 1], color='purple', label='Bashorat (2-ustun)')
plt.plot(X_test, y_pred[:, 2], color='brown', label='Bashorat (3-ustun)')

# %%
plt.scatter(X_test, y_test[:, 0], label='Haqiqiy (1-ustun)', color='blue')
plt.scatter(X_test, y_test[:, 1], label='Haqiqiy (2-ustun)', color='green')
plt.scatter(X_test, y_test[:, 2], label='Haqiqiy (3-ustun)', color='orange')

plt.plot(X_test, y_pred[:, 0], color='red', label='Bashorat (1-ustun)')
plt.plot(X_test, y_pred[:, 1], color='purple', label='Bashorat (2-ustun)')
plt.plot(X_test, y_pred[:, 2], color='brown', label='Bashorat (3-ustun)')
plt.title("Parabola: y = 2x^2 + 3x + 1")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc="lower right", bbox_to_anchor=(1, 0)
)
plt.grid(True)
plt.show()
